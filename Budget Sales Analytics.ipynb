# %% [markdown]
# #                                   Project Title: Budget Sales Analysis

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Extracting Excel Dataset From System Using Pandas Library

Calendar = pd.read_excel('Calendar.xlsx')
Calendar.head(10)
# Out:
#         Date   DateKey  Year Quarter  MonthNum Month FiscalYear FiscalQuarter  \
# 0 2016-04-03  20160403  2016      Q2         4   Apr     FY2016           FQ4
# 1 2016-04-04  20160404  2016      Q2         4   Apr     FY2016           FQ4
# 2 2016-04-05  20160405  2016      Q2         4   Apr     FY2016           FQ4
# 3 2016-04-06  20160406  2016      Q2         4   Apr     FY2016           FQ4
# 4 2016-04-07  20160407  2016      Q2         4   Apr     FY2016           FQ4
# 5 2016-04-08  20160408  2016      Q2         4   Apr     FY2016           FQ4
# 6 2016-04-09  20160409  2016      Q2         4   Apr     FY2016           FQ4
# 7 2016-04-10  20160410  2016      Q2         4   Apr     FY2016           FQ4
# 8 2016-04-11  20160411  2016      Q2         4   Apr     FY2016           FQ4
# 9 2016-07-04  20160704  2016      Q3         7   Jul     FY2017           FQ1
#
#    FiscalMonthNum FiscalMonth MonthYear MonthYearLong  MonthYearNum  \
# 0              10         Apr    Apr-16      Apr-2016        201604
# 1              10         Apr    Apr-16      Apr-2016        201604
# 2              10         Apr    Apr-16      Apr-2016        201604
# 3              10         Apr    Apr-16      Apr-2016        201604
# 4              10         Apr    Apr-16      Apr-2016        201604
# 5              10         Apr    Apr-16      Apr-2016        201604
# 6              10         Apr    Apr-16      Apr-2016        201604
# 7              10         Apr    Apr-16      Apr-2016        201604
# 8              10         Apr    Apr-16      Apr-2016        201604
# 9               1         Jul    Jul-16      Jul-2016        201607
#
#    WeekdayNum Weekday WeekdayWeekend
# 0           1     Sun        Weekend
# 1           2     Mon        Weekday
# 2           3     Tue        Weekday
# 3           4     Wed        Weekday
# 4           5     Thu        Weekday
# 5           6     Fri        Weekday
# 6           7     Sat        Weekend
# 7           1     Sun        Weekend
# 8           2     Mon        Weekday
# 9           2     Mon        Weekday

# %%
#Extracting Excel Dataset From System Using Pandas Library

Customers = pd.read_excel('Customers.xlsx')
Customers.head(10)
# Out:
#    CustomerKey  FirstName LastName            FullName  BirthDate  \
# 0        11000        Jon     Yang           Yang, Jon 1966-04-08
# 1        11001     Eugene    Huang       Huang, Eugene 1965-05-14
# 2        11002      Ruben   Torres       Torres, Ruben 1965-08-12
# 3        11003    Christy      Zhu        Zhu, Christy 1968-02-15
# 4        11004  Elizabeth  Johnson  Johnson, Elizabeth 1968-08-08
# 5        11005      Julio     Ruiz         Ruiz, Julio 1965-08-05
# 6        11006      Janet  Alvarez      Alvarez, Janet 1965-12-06
# 7        11007      Marco    Mehta        Mehta, Marco 1964-05-09
# 8        11008        Rob  Verhoff        Verhoff, Rob 1964-07-07
# 9        11009    Shannon  Carlson    Carlson, Shannon 1964-04-01
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M         90000              2                     0
# 1             S      M         60000              3                     3
# 2             M      M         60000              3                     3
# 3             S      F         70000              0                     0
# 4             S      F         80000              5                     5
# 5             S      M         70000              0                     0
# 6             S      F         70000              0                     0
# 7             M      M         60000              3                     3
# 8             S      F         60000              4                     4
# 9             S      M         70000              0                     0
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned  \
# 0  Bachelors  Professional               1                0
# 1  Bachelors  Professional               0                1
# 2  Bachelors  Professional               1                1
# 3  Bachelors  Professional               0                1
# 4  Bachelors  Professional               1                4
# 5  Bachelors  Professional               1                1
# 6  Bachelors  Professional               1                1
# 7  Bachelors  Professional               1                2
# 8  Bachelors  Professional               1                3
# 9  Bachelors  Professional               0                1
#
#           AddressLine1 DateFirstPurchase CommuteDistance
# 0      3761 N. 14th St        2014-01-22       1-2 Miles
# 1           2243 W St.        2014-01-18       0-1 Miles
# 2     5844 Linden Land        2014-01-10       2-5 Miles
# 3     1825 Village Pl.        2014-01-01      5-10 Miles
# 4  7553 Harness Circle        2014-01-26       1-2 Miles
# 5  7305 Humphrey Drive        2014-01-02      5-10 Miles
# 6        2612 Berry Dr        2014-01-27      5-10 Miles
# 7     942 Brook Street        2014-01-12       0-1 Miles
# 8     624 Peabody Road        2014-01-28       10+ Miles
# 9  3839 Northgate Road        2014-01-30      5-10 Miles

# %%
Customers.columns
# Out:
# Index(['CustomerKey', 'FirstName', 'LastName', 'FullName', 'BirthDate',
#        'MaritalStatus', 'Gender', 'YearlyIncome', 'TotalChildren',
#        'NumberChildrenAtHome', 'Education', 'Occupation', 'HouseOwnerFlag',
#        'NumberCarsOwned', 'AddressLine1', 'DateFirstPurchase',
#        'CommuteDistance'],
#       dtype='object')

# %%
#Extracting Excel Dataset From System Using Pandas Library

Product = pd.read_excel('Product.xlsx')
Product.head(10)
# Out:
#    ProductKey            ProductName SubCategory Category  StandardCost  \
# 0           1        Adjustable Race         NaN      NaN           NaN
# 1           2           Bearing Ball         NaN      NaN           NaN
# 2           3        BB Ball Bearing         NaN      NaN           NaN
# 3           4  Headset Ball Bearings         NaN      NaN           NaN
# 4           5                  Blade         NaN      NaN           NaN
# 5           6            LL Crankarm         NaN      NaN           NaN
# 6           7            ML Crankarm         NaN      NaN           NaN
# 7           8            HL Crankarm         NaN      NaN           NaN
# 8           9        Chainring Bolts         NaN      NaN           NaN
# 9          10          Chainring Nut         NaN      NaN           NaN
#
#     Color  ListPrice  DaysToManufacture ProductLine ModelName  \
# 0     NaN        NaN                  0         NaN       NaN
# 1     NaN        NaN                  0         NaN       NaN
# 2     NaN        NaN                  1         NaN       NaN
# 3     NaN        NaN                  0         NaN       NaN
# 4     NaN        NaN                  1         NaN       NaN
# 5   Black        NaN                  0         NaN       NaN
# 6   Black        NaN                  0         NaN       NaN
# 7   Black        NaN                  0         NaN       NaN
# 8  Silver        NaN                  0         NaN       NaN
# 9  Silver        NaN                  0         NaN       NaN
#
#                                                Photo ProductDescription  \
# 0  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# 1  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# 2  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# 3  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# 4  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# 5  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# 6  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# 7  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# 8  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# 9  http://www.avising.com/me/LearnPBI/DataSources...                NaN
#
#    StartDate
# 0 1998-06-01
# 1 1998-06-01
# 2 1998-06-01
# 3 1998-06-01
# 4 1998-06-01
# 5 1998-06-01
# 6 1998-06-01
# 7 1998-06-01
# 8 1998-06-01
# 9 1998-06-01

# %%
Product.columns
# Out:
# Index(['ProductKey', 'ProductName', 'SubCategory', 'Category', 'StandardCost',
#        'Color', 'ListPrice', 'DaysToManufacture', 'ProductLine', 'ModelName',
#        'Photo', 'ProductDescription', 'StartDate'],
#       dtype='object')

# %%
#Extracting Excel Dataset From System Using Pandas Library

Sales = pd.read_excel('Sales.xlsx')
Sales.head(10)
# Out:
#    ProductKey  OrderDate   ShipDate  CustomerKey  PromotionKey  \
# 0         310 2014-01-01 2014-01-08        21768             1
# 1         346 2014-01-01 2014-01-08        28389             1
# 2         346 2014-01-01 2014-01-08        25863             1
# 3         336 2014-01-01 2014-01-08        14501             1
# 4         346 2014-01-01 2014-01-08        11003             1
# 5         311 2014-01-02 2014-01-09        27645             1
# 6         310 2014-01-02 2014-01-09        16624             1
# 7         351 2014-01-02 2014-01-09        11005             1
# 8         344 2014-01-02 2014-01-09        11011             1
# 9         312 2014-01-03 2014-01-10        27621             1
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  OrderQuantity  \
# 0                  6          SO43697                     1              2
# 1                  7          SO43698                     1              2
# 2                  1          SO43699                     1              2
# 3                  4          SO43700                     1              2
# 4                  9          SO43701                     1              2
# 5                  4          SO43702                     1              4
# 6                  9          SO43703                     1              4
# 7                  9          SO43704                     1              4
# 8                  9          SO43705                     1              4
# 9                  4          SO43706                     1              1
#
#    UnitPrice  TotalProductCost  SalesAmount    TaxAmt
# 0  1789.1350         2171.2942    3578.2700  286.2616
# 1  1699.9950         1912.1544    3399.9900  271.9992
# 2  1699.9950         1912.1544    3399.9900  271.9992
# 3   349.5491          413.1463     699.0982   55.9279
# 4  1699.9950         1912.1544    3399.9900  271.9992
# 5   894.5675         2171.2942    3578.2700  286.2616
# 6   894.5675         2171.2942    3578.2700  286.2616
# 7   843.7475         1898.0944    3374.9900  269.9992
# 8   849.9975         1912.1544    3399.9900  271.9992
# 9  3578.2700         2171.2942    3578.2700  286.2616

# %%
Sales.columns
# Out:
# Index(['ProductKey', 'OrderDate', 'ShipDate', 'CustomerKey', 'PromotionKey',
#        'SalesTerritoryKey', 'SalesOrderNumber', 'SalesOrderLineNumber',
#        'OrderQuantity', 'UnitPrice', 'TotalProductCost', 'SalesAmount',
#        'TaxAmt'],
#       dtype='object')

# %%
#Extracting Excel Dataset From System Using Pandas Library

Territory = pd.read_excel('Territory.xlsx')
Territory.head(10)
# Out:
#    SalesTerritoryKey          Region         Country          Group  \
# 0                  1       Northwest   United States  North America
# 1                  2       Northeast   United States  North America
# 2                  3         Central   United States  North America
# 3                  4       Southwest   United States  North America
# 4                  5       Southeast   United States  North America
# 5                  6          Canada          Canada  North America
# 6                  7          France          France         Europe
# 7                  8         Germany         Germany         Europe
# 8                  9       Australia       Australia        Pacific
# 9                 10  United Kingdom  United Kingdom         Europe
#
#                                          RegionImage
# 0  http://www.avising.com/me/LearnPBI/DataSources...
# 1  http://www.avising.com/me/LearnPBI/DataSources...
# 2  http://www.avising.com/me/LearnPBI/DataSources...
# 3  http://www.avising.com/me/LearnPBI/DataSources...
# 4  http://www.avising.com/me/LearnPBI/DataSources...
# 5  http://www.avising.com/me/LearnPBI/DataSources...
# 6  http://www.avising.com/me/LearnPBI/DataSources...
# 7  http://www.avising.com/me/LearnPBI/DataSources...
# 8  http://www.avising.com/me/LearnPBI/DataSources...
# 9  http://www.avising.com/me/LearnPBI/DataSources...

# %%
Territory.columns
# Out:
# Index(['SalesTerritoryKey', 'Region', 'Country', 'Group', 'RegionImage'], dtype='object')

# %%
#Extracting Excel Dataset From System Using Pandas Library

Budget = pd.read_excel('Budget.xlsx')
Budget.head(10)
# Out:
#                Category        Subcategory              ProductName  \
# 0           Accessories         Bike Racks      Hitch Rack - 4-Bike
# 1           Accessories        Bike Stands   All-Purpose Bike Stand
# 2           Accessories  Bottles and Cages    Water Bottle - 30 oz.
# 3           Accessories           Cleaners    Bike Wash - Dissolver
# 4           Accessories            Fenders    Fender Set - Mountain
# 5           Accessories            Helmets    Sport-100 Helmet, Red
# 6           Accessories    Hydration Packs  Hydration Pack - 70 oz.
# 7           Accessories    Tires and Tubes      Patch Kit/8 Patches
# 8  SubTotal Accessories                NaN                      NaN
# 9                 Bikes     Mountain Bikes  Mountain-100 Silver, 38
#
#    ProductKey  Jan, 2016  Feb, 2016  Mar, 2016  Apr, 2016  May, 2016  \
# 0       483.0       1131       2635       4134       2179       2637
# 1       486.0        666       3695       2868       4862       3439
# 2       477.0       1892       4727       3656       4449       4051
# 3       484.0        160        713        555        656        369
# 4       485.0        970       3014       2809       4259       3638
# 5       212.0       5317      16221      16752      16552      17204
# 6       487.0        809       2684       2917       3425       2716
# 7       480.0       3554      18758      20905      18046      21680
# 8         NaN      14499      52447      54596      54428      55734
# 9       344.0     370105     326786     384811     439822     458523
#
#    Jun, 2016  Jul, 2016  Aug, 2016  Sep, 2016  Oct, 2016  Nov, 2016  \
# 0       3279       2218       3287       3885       2484       5441
# 1       4612       2774       3003       2401       4413       3881
# 2       6257       4871       5231       5461       5529       5220
# 3        582        777        777        239        496        686
# 4       3721       4190       3618       3975       3892       4740
# 5      25354      17584      20409      18268      20567      25571
# 6       3260       3773       3523       4252       3111       4985
# 7      22456      23995      22922      20950      21905      24019
# 8      69521      60182      62770      59431      62397      74543
# 9     619456     524348     647048     557368     615032     802831
#
#    Dec, 2016  Grand Total
# 0       3551        36861
# 1       2143        38757
# 2       6025        57369
# 3        455         6465
# 4       4844        43670
# 5      22106       221905
# 6       4348        39803
# 7      23587       242777
# 8      67059       687607
# 9     788234      6534364

# %%
Budget.columns
# Out:
# Index(['Category', 'Subcategory', 'ProductName', 'ProductKey', 'Jan, 2016',
#        'Feb, 2016', 'Mar, 2016', 'Apr, 2016', 'May, 2016', 'Jun, 2016',
#        'Jul, 2016', 'Aug, 2016', 'Sep, 2016', 'Oct, 2016', 'Nov, 2016',
#        'Dec, 2016', 'Grand Total'],
#       dtype='object')

# %%
# Merging Sales data with Customers data

MergedData = pd.merge(Sales, Customers, on = 'CustomerKey')

# %%
# Merging Sales, Customers and Product data

MergedData = pd.merge(MergedData, Product, on = 'ProductKey')

# %%
# Merging Sales, Customers, Product and Territory data

MergedData = pd.merge(MergedData, Territory, on = 'SalesTerritoryKey')

# %%
MergedData.head(10)
# Out:
#    ProductKey  OrderDate   ShipDate  CustomerKey  PromotionKey  \
# 0         310 2014-01-01 2014-01-08        21768             1
# 1         310 2014-01-30 2014-02-06        21727             1
# 2         310 2014-02-23 2014-02-28        21921             1
# 3         310 2014-02-28 2014-03-06        22050             1
# 4         310 2014-05-18 2014-05-25        22233             1
# 5         310 2014-05-18 2014-05-25        22121             1
# 6         310 2014-06-08 2014-06-15        22299             1
# 7         310 2014-06-21 2014-06-28        22247             1
# 8         310 2014-06-24 2014-06-30        22252             1
# 9         310 2014-07-03 2014-07-10        22785             1
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  OrderQuantity  \
# 0                  6          SO43697                     1              2
# 1                  6          SO43833                     1              4
# 2                  6          SO44027                     1              1
# 3                  6          SO44064                     1              1
# 4                  6          SO44677                     1              2
# 5                  6          SO44678                     1              2
# 6                  6          SO44851                     1              1
# 7                  6          SO44957                     1              1
# 8                  6          SO44983                     1              4
# 9                  6          SO45094                     1              1
#
#    UnitPrice  ...  DaysToManufacture  ProductLine  ModelName  \
# 0  1789.1350  ...                  4         Road   Road-150
# 1   894.5675  ...                  4         Road   Road-150
# 2  3578.2700  ...                  4         Road   Road-150
# 3  3578.2700  ...                  4         Road   Road-150
# 4  1789.1350  ...                  4         Road   Road-150
# 5  1789.1350  ...                  4         Road   Road-150
# 6  3578.2700  ...                  4         Road   Road-150
# 7  3578.2700  ...                  4         Road   Road-150
# 8   894.5675  ...                  4         Road   Road-150
# 9  3578.2700  ...                  4         Road   Road-150
#
#                                                Photo  \
# 0  http://www.avising.com/me/LearnPBI/DataSources...
# 1  http://www.avising.com/me/LearnPBI/DataSources...
# 2  http://www.avising.com/me/LearnPBI/DataSources...
# 3  http://www.avising.com/me/LearnPBI/DataSources...
# 4  http://www.avising.com/me/LearnPBI/DataSources...
# 5  http://www.avising.com/me/LearnPBI/DataSources...
# 6  http://www.avising.com/me/LearnPBI/DataSources...
# 7  http://www.avising.com/me/LearnPBI/DataSources...
# 8  http://www.avising.com/me/LearnPBI/DataSources...
# 9  http://www.avising.com/me/LearnPBI/DataSources...
#
#                                   ProductDescription  StartDate  Region  \
# 0  This bike is ridden by race winners. Developed... 2005-07-01  Canada
# 1  This bike is ridden by race winners. Developed... 2005-07-01  Canada
# 2  This bike is ridden by race winners. Developed... 2005-07-01  Canada
# 3  This bike is ridden by race winners. Developed... 2005-07-01  Canada
# 4  This bike is ridden by race winners. Developed... 2005-07-01  Canada
# 5  This bike is ridden by race winners. Developed... 2005-07-01  Canada
# 6  This bike is ridden by race winners. Developed... 2005-07-01  Canada
# 7  This bike is ridden by race winners. Developed... 2005-07-01  Canada
# 8  This bike is ridden by race winners. Developed... 2005-07-01  Canada
# 9  This bike is ridden by race winners. Developed... 2005-07-01  Canada
#
#   Country          Group                                        RegionImage
# 0  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
# 1  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
# 2  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
# 3  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
# 4  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
# 5  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
# 6  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
# 7  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
# 8  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
# 9  Canada  North America  http://www.avising.com/me/LearnPBI/DataSources...
#
# [10 rows x 45 columns]

# %% [markdown]
# # Evaluating the missing values

# %%
# Dimensions of Data

MergedData.shape
# Out:
# (58189, 45)

# %%
MergedData.describe()
# Out:
#          ProductKey                      OrderDate  \
# count  58189.000000                          58189
# mean     437.208304  2016-06-03 03:56:09.605939200
# min      214.000000            2014-01-01 00:00:00
# 25%      358.000000            2016-04-01 00:00:00
# 50%      479.000000            2016-07-07 00:00:00
# 75%      529.000000            2016-10-10 00:00:00
# max      606.000000            2016-12-30 00:00:00
# std      118.099746                            NaN
#
#                             ShipDate   CustomerKey  PromotionKey  \
# count                          58189  58189.000000  58189.000000
# mean   2016-06-10 04:03:24.657237760  18853.004640      1.043427
# min              2014-01-08 00:00:00  11000.000000      1.000000
# 25%              2016-04-08 00:00:00  14012.000000      1.000000
# 50%              2016-07-14 00:00:00  18151.000000      1.000000
# 75%              2016-10-17 00:00:00  23450.000000      1.000000
# max              2017-01-07 00:00:00  29483.000000     14.000000
# std                              NaN   5433.374315      0.348948
#
#        SalesTerritoryKey  SalesOrderLineNumber  OrderQuantity     UnitPrice  \
# count       58189.000000          58189.000000   58189.000000  58189.000000
# mean            6.261716              1.887453       1.569386    413.888218
# min             1.000000              1.000000       1.000000      0.572500
# 25%             4.000000              1.000000       1.000000      4.990000
# 50%             7.000000              2.000000       1.000000     24.490000
# 75%             9.000000              2.000000       2.000000    269.995000
# max            10.000000              8.000000       4.000000   3578.270000
# std             2.960248              1.018829       1.047532    833.052938
#
#        TotalProductCost  ...   YearlyIncome  TotalChildren  \
# count      58189.000000  ...   58189.000000   58189.000000
# mean         296.539185  ...   59769.887779       1.838921
# min            0.856500  ...   10000.000000       0.000000
# 25%            3.362300  ...   30000.000000       0.000000
# 50%           12.192400  ...   60000.000000       2.000000
# 75%          343.649600  ...   80000.000000       3.000000
# max         2171.294200  ...  170000.000000       5.000000
# std          560.171436  ...   33128.041818       1.614467
#
#       NumberChildrenAtHome  HouseOwnerFlag  NumberCarsOwned  \
# count         58189.000000    58189.000000     58189.000000
# mean              1.073502        0.690560         1.502466
# min               0.000000        0.000000         0.000000
# 25%               0.000000        0.000000         1.000000
# 50%               0.000000        1.000000         2.000000
# 75%               2.000000        1.000000         2.000000
# max               5.000000        1.000000         4.000000
# std               1.580055        0.462267         1.155496
#
#                    DateFirstPurchase  StandardCost     ListPrice  \
# count                          58189  58189.000000  58189.000000
# mean   2015-12-23 02:50:33.356819968    296.539185    503.666270
# min              2014-01-01 00:00:00      0.856500      2.290000
# 25%              2015-06-21 00:00:00      3.362300      8.990000
# 50%              2016-03-12 00:00:00     12.192400     32.600000
# 75%              2016-07-26 00:00:00    343.649600    539.990000
# max              2016-12-30 00:00:00   2171.294200   3578.270000
# std                              NaN    560.171436    941.462817
#
#       DaysToManufacture                      StartDate
# count      58189.000000                          58189
# mean           1.045215  2007-05-14 02:44:51.848974848
# min            0.000000            2005-07-01 00:00:00
# 25%            0.000000            2007-07-01 00:00:00
# 50%            0.000000            2007-07-01 00:00:00
# 75%            4.000000            2007-07-01 00:00:00
# max            4.000000            2007-07-01 00:00:00
# std            1.757395                            NaN
#
# [8 rows x 23 columns]

# %%
# Fields and information of dataset

MergedData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58189 entries, 0 to 58188
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductKey            58189 non-null  int64
#  1   OrderDate             58189 non-null  datetime64[ns]
#  2   ShipDate              58189 non-null  datetime64[ns]
#  3   CustomerKey           58189 non-null  int64
#  4   PromotionKey          58189 non-null  int64
#  5   SalesTerritoryKey     58189 non-null  int64
#  6   SalesOrderNumber      58189 non-null  object
#  7   SalesOrderLineNumber  58189 non-null  int64
#  8   OrderQuantity         58189 non-null  int64
#  9   UnitPrice             58189 non-null  float64
#  10  TotalProductCost      58189 non-null  float64
#  11  SalesAmount           58189 non-null  float64
#  12  TaxAmt                58189 non-null  float64
#  13  FirstName             58189 non-null  object
#  14  LastName              58189 non-null  object
#  15  FullName              58189 non-null  object
#  16  BirthDate             58189 non-null  datetime64[ns]
#  17  MaritalStatus         58189 non-null  object
#  18  Gender                58189 non-null  object
#  19  YearlyIncome          58189 non-null  int64
#  20  TotalChildren         58189 non-null  int64
#  21  NumberChildrenAtHome  58189 non-null  int64
#  22  Education             58189 non-null  object
#  23  Occupation            58189 non-null  object
#  24  HouseOwnerFlag        58189 non-null  int64
#  25  NumberCarsOwned       58189 non-null  int64
#  26  AddressLine1          58189 non-null  object
#  27  DateFirstPurchase     58189 non-null  datetime64[ns]
#  28  CommuteDistance       58189 non-null  object
#  29  ProductName           58189 non-null  object
#  30  SubCategory           58189 non-null  object
#  31  Category              58189 non-null  object
#  32  StandardCost          58189 non-null  float64
#  33  Color                 30747 non-null  object
#  34  ListPrice             58189 non-null  float64
#  35  DaysToManufacture     58189 non-null  int64
#  36  ProductLine           58189 non-null  object
#  37  ModelName             58189 non-null  object
#  38  Photo                 58189 non-null  object
#  39  ProductDescription    58189 non-null  object
#  40  StartDate             58189 non-null  datetime64[ns]
#  41  Region                58189 non-null  object
#  42  Country               58189 non-null  object
#  43  Group                 58189 non-null  object
#  44  RegionImage           58189 non-null  object
# dtypes: datetime64[ns](5), float64(6), int64(12), object(22)
# memory usage: 20.0+ MB

# %%
MergedData.Gender.value_counts()
# Out:
# Gender
# M    29314
# F    28875
# Name: count, dtype: int64

# %%
Clean_Data = MergedData.copy()

# %% [markdown]
# # Droping the ususeful fields in dataset

# %%
Clean_Data.drop(columns =['ProductKey','PromotionKey','SalesTerritoryKey','SalesOrderNumber','SalesOrderLineNumber','FirstName','LastName','FullName','AddressLine1','DaysToManufacture','ProductLine','Photo','ProductDescription','Region','Group','RegionImage'],axis=1,inplace=True)

# %%
Clean_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58189 entries, 0 to 58188
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             58189 non-null  datetime64[ns]
#  1   ShipDate              58189 non-null  datetime64[ns]
#  2   CustomerKey           58189 non-null  int64
#  3   OrderQuantity         58189 non-null  int64
#  4   UnitPrice             58189 non-null  float64
#  5   TotalProductCost      58189 non-null  float64
#  6   SalesAmount           58189 non-null  float64
#  7   TaxAmt                58189 non-null  float64
#  8   BirthDate             58189 non-null  datetime64[ns]
#  9   MaritalStatus         58189 non-null  object
#  10  Gender                58189 non-null  object
#  11  YearlyIncome          58189 non-null  int64
#  12  TotalChildren         58189 non-null  int64
#  13  NumberChildrenAtHome  58189 non-null  int64
#  14  Education             58189 non-null  object
#  15  Occupation            58189 non-null  object
#  16  HouseOwnerFlag        58189 non-null  int64
#  17  NumberCarsOwned       58189 non-null  int64
#  18  DateFirstPurchase     58189 non-null  datetime64[ns]
#  19  CommuteDistance       58189 non-null  object
#  20  ProductName           58189 non-null  object
#  21  SubCategory           58189 non-null  object
#  22  Category              58189 non-null  object
#  23  StandardCost          58189 non-null  float64
#  24  Color                 30747 non-null  object
#  25  ListPrice             58189 non-null  float64
#  26  ModelName             58189 non-null  object
#  27  StartDate             58189 non-null  datetime64[ns]
#  28  Country               58189 non-null  object
# dtypes: datetime64[ns](5), float64(6), int64(7), object(11)
# memory usage: 12.9+ MB

# %%
# Dimensions of clean data

Clean_Data.shape
# Out:
# (58189, 29)

# %%
g=Clean_Data.groupby('Gender')['CustomerKey'].count()
g
# Out:
# Gender
# F    28875
# M    29314
# Name: CustomerKey, dtype: int64

# %%
# Gendar Distribution of Customers by ploting pie chart

plt.figure(figsize=(5,5))
plt.pie(g,labels=['Female','Male'], autopct= '%0.0f%%')
plt.title('Gender Distribution of Customers', fontsize=20)
plt.show()

# %% [markdown]
# Male and  Female customers are equal

# %%
m=Clean_Data.groupby('MaritalStatus')['CustomerKey'].count()
m
# Out:
# MaritalStatus
# M    31992
# S    26197
# Name: CustomerKey, dtype: int64

# %%
# Evaluting relationship between Country and Sales by plot

plt.figure(figsize=(3,5))
plt.pie(g,labels=['Married','Single'], autopct= '%0.0f%%')
plt.title('Marital Distribution of Customers', fontsize=20)
plt.show()

# %% [markdown]
# There are more married customers than single customers. The difference is not sharp but is considerable.

# %%
# Evaluting relationship between Total children and no of customers by plotting bar garph

sns.set_style('whitegrid')
tnd = sns.countplot(x='TotalChildren', data=Clean_Data)
plt.title('Count of Customers vs Total Children', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Count of Customers vs Total Children')

# %% [markdown]
# Customers with more than 2 children are very less as compared to the customers with children less than 3.

# %%
# Evaluting relationship between Education of customers and no of customers by plotting bar garph

plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
plt.xticks(rotation=45)
plt.title('Count of Customers vs Education', fontsize=15)
sns.countplot(x='Education', data=Clean_Data)
# Out:
# <Axes: title={'center': 'Count of Customers vs Education'}, xlabel='Education', ylabel='count'>

# %% [markdown]
# Most of the customers are graduates or have Partial College education.

# %%
# Evaluting relationship between Occupation of customers and no of customers by plotting bar garph

plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
plt.xticks(rotation=45)
plt.title('Count of Customers vs Occupation', fontsize=15)
sns.countplot(x='Occupation', data=Clean_Data)
# Out:
# <Axes: title={'center': 'Count of Customers vs Occupation'}, xlabel='Occupation', ylabel='count'>

# %% [markdown]
# Most of the customers are Professional, Skilled Manual and Management occupation.

# %%
# Evaluting relationship between Commute Distance and no of customers by plotting bar garph

plt.figure(figsize=(5,5))
sns.set_style('whitegrid')
plt.xticks(rotation=45)
plt.title('Count of Customers vs Commute Distance', fontsize=15)
sns.countplot(x='CommuteDistance', data=Clean_Data)
# Out:
# <Axes: title={'center': 'Count of Customers vs Commute Distance'}, xlabel='CommuteDistance', ylabel='count'>

# %% [markdown]
# Most of the customers are those who has less commute distance 0-1 miles. Other customers who has commute distance between 1 to 10, has nearly have same customers count.

# %%
c=Clean_Data.groupby('Category')['CustomerKey'].count()
c
# Out:
# Category
# Accessories    34319
# Bikes          15205
# Clothing        8665
# Name: CustomerKey, dtype: int64

# %%
# Category distribution of customers by plotting pie chart

plt.figure(figsize=(5,5))
plt.pie(c,labels=['Accessories','Bikes','Clothing'], autopct= '%0.0f%%')
plt.title('Category Distribution of Customers', fontsize=20)
plt.show()

# %% [markdown]
# Most of the customers are buying Accessories.

# %%
# Evaluting relationship between sub category Category of product purchased and no of customers by plotting bar graph

plt.figure(figsize=(15,6))
plt.xticks(rotation=45)
plt.xticks(rotation=45)
plt.title('Count of customers vs Sub category')
sns.set_context("paper", font_scale=2)
sns.set_style('whitegrid')
sns.countplot(x='SubCategory',data=Clean_Data)
# Out:
# <Axes: title={'center': 'Count of customers vs Sub category'}, xlabel='SubCategory', ylabel='count'>

# %% [markdown]
# Most of the customers are interested in buying accessories like bottles,cages,tires, tubes. Within the bike category segment, road and mountain bikes are more sold.

# %%
# Evaluting relationship between Country and no of customers by plotting bar graph

sns.set_style('whitegrid')
plt.title('Count of customers vs Country')
sns.countplot(x='Country',data=Clean_Data)
sns.set_context("paper", font_scale=1.2)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Canada'),
#   Text(1, 0, 'Australia'),
#   Text(2, 0, 'United States'),
#   Text(3, 0, 'United Kingdom'),
#   Text(4, 0, 'Germany'),
#   Text(5, 0, 'France')])

# %% [markdown]
# Most of customers are from United States and Australia.

# %%
co=Clean_Data.groupby('Country')['CustomerKey'].count()
co
# Out:
# Country
# Australia         12972
# Canada             7142
# France             5382
# Germany            5460
# United Kingdom     6709
# United States     20524
# Name: CustomerKey, dtype: int64

# %%
# Country distribution of customers by plotting pie chart

plt.figure(figsize=(5,5))
plt.pie(co,labels=['Australia','Canada ','France','Germany','United Kingdom','United States'], autopct= '%0.0f%%')
plt.title('Country Distribution of Customers', fontsize=20)
plt.show()

# %% [markdown]
# More than of 50% customers are from United States and Australia.

# %%
# Evaluting relationship between Country and Sales by ploting Line graph

salesYearlyIncome = Clean_Data.groupby('YearlyIncome').SalesAmount.sum()
plt.figure(figsize=(15,6))
plt.xlabel("Yearly Income", size=15)
plt.ylabel("Sales Amount", size=15)
plt.title('Sales vs Yearly Income', fontsize=20)
plt.grid()
salesYearlyIncome.plot(kind='line')
# Out:
# <Axes: title={'center': 'Sales vs Yearly Income'}, xlabel='YearlyIncome', ylabel='Sales Amount'>

# %% [markdown]
# Most of the sales comes from middle class people with yearly income from 30,000 to 70,000 Dollars.

# %%
# Evaluting relationship between total children and Sales by ploting bar graph

salesTotalChildren = Clean_Data.groupby('TotalChildren').SalesAmount.sum()
plt.figure(figsize=(10,8))
plt.xlabel("TotalChildren", size=15)
plt.ylabel("Sales Amount", size=15)
plt.xticks(fontsize= 13)
plt.yticks(fontsize= 13)
plt.title('Sales vs Total Children', fontsize=20)
plt.grid()
salesTotalChildren.plot(kind='bar')
# Out:
# <Axes: title={'center': 'Sales vs Total Children'}, xlabel='TotalChildren', ylabel='Sales Amount'>

# %%
Most of the sales comes from the customers having 0 to 2 children.

# %%
# Evaluting relationship between education and Sales by ploting bar graph

salesEducation = Clean_Data.groupby('Education').SalesAmount.sum()
plt.figure(figsize=(15,6))
plt.xlabel("Education", size=15)
plt.ylabel("Sales Amount", size=15)
plt.xticks(fontsize= 13)
plt.yticks(fontsize= 13)
plt.title('Sales vs Education', fontsize=20)
plt.grid()
salesEducation.plot(kind='bar')
# Out:
# <Axes: title={'center': 'Sales vs Education'}, xlabel='Education', ylabel='Sales Amount'>

# %% [markdown]
# Most of the sales comes from customers with Bachelors and Partial college education.

# %%
# Evaluting relationship between Occupation and Sales by ploting bar graph

salesOccupation = Clean_Data.groupby('Occupation').SalesAmount.sum()
plt.figure(figsize=(15,6))
plt.xlabel("Occupation", size=15)
plt.ylabel("Sales Amount", size=15)
plt.xticks(fontsize= 13)
plt.yticks(fontsize= 13)
plt.title('Sales vs Occupation', fontsize=20)
plt.grid()
salesOccupation.plot(kind='bar')
# Out:
# <Axes: title={'center': 'Sales vs Occupation'}, xlabel='Occupation', ylabel='Sales Amount'>

# %% [markdown]
# Professionals contributes most to the sales of company.

# %%
# Evaluting relationship between Commute Distance and Sales by ploting bar graph

salesCommuteDistance = Clean_Data.groupby('CommuteDistance').SalesAmount.sum()
plt.figure(figsize=(15,6))
plt.xlabel("CommuteDistance", size=15)
plt.ylabel("Sales Amount", size=15)
plt.xticks(fontsize= 13)
plt.yticks(fontsize= 13)
plt.title('Sales vs Commute Distance', fontsize=20)
plt.grid()
salesCommuteDistance.plot(kind='bar')
# Out:
# <Axes: title={'center': 'Sales vs Commute Distance'}, xlabel='CommuteDistance', ylabel='Sales Amount'>

# %% [markdown]
# Customers with less commute distance contribute to higher sales in company.

# %%
# Evaluting relationship between Sub Category and Sales by ploting bar graph

salesSubCategory = Clean_Data.groupby('SubCategory').SalesAmount.sum()
plt.figure(figsize=(15,6))
plt.xlabel("SubCategory", size=15)
plt.ylabel("Sales Amount", size=15)
plt.xticks(fontsize= 13)
plt.yticks(fontsize= 13)
plt.title('Sales vs Sub Category', fontsize=20)
plt.grid()
salesSubCategory.plot(kind='bar')
# Out:
# <Axes: title={'center': 'Sales vs Sub Category'}, xlabel='SubCategory', ylabel='Sales Amount'>

# %% [markdown]
# Majority of sales comes from Road Bikes abd Mountain Bikes.

# %%
# Evaluting relationship between Birth Date and Sales by ploting Line graph

salesBirthDate = Clean_Data.groupby('BirthDate').SalesAmount.sum()
plt.figure(figsize=(12,6))
plt.xlabel("BiRthDate", size=12)
plt.ylabel("Sales Amount", size=12)
plt.title('Sales vs BirthDate', fontsize=20)
plt.grid()
salesBirthDate.plot(kind='line')
# Out:
# <Axes: title={'center': 'Sales vs BirthDate'}, xlabel='BirthDate', ylabel='Sales Amount'>

# %% [markdown]
# People with age from 47 to 72 gave most of the sales.
